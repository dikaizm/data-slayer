# %%
import pickle

with open('../data/processed/train-processed-v4.pkl', 'rb') as f:
    train = pickle.load(f)
    
with open('../data/processed/test-processed-v4.pkl', 'rb') as f:
    test = pickle.load(f)
    
train.columns.to_numpy()
# Out:
# array(['Fuel Consumption City (l/100km)',
#        'Fuel Consumption Hwy (l/100km)',
#        'Fuel Consumption Comb (l/100km)', 'Engine Size(L)', 'Cylinders',
#        'Id', 'Make', 'Vehicle Class', 'Transmission', 'Fuel Type',
#        'CO2 Emissions(g/km)'], dtype=object)

# %%
train.dtypes
# Out:
# Fuel Consumption City (l/100km)    float64
# Fuel Consumption Hwy (l/100km)     float64
# Fuel Consumption Comb (l/100km)    float64
# Engine Size(L)                     float64
# Cylinders                          float64
# Id                                   int64
# Make                               float64
# Vehicle Class                      float64
# Transmission                       float64
# Fuel Type                          float64
# CO2 Emissions(g/km)                float64
# dtype: object

# %%
total_data = len(train) + len(test)
train_test_ratio = (len(test) / total_data) * 100

print(f'Total number of data points: {total_data}')
print(f'Number of data points in training set: {len(train)}')
print(f'Number of data points in test set: {len(test)}')
print(f'Ratio of train to test data: {train_test_ratio:.2f}%')
# Out:
# Total number of data points: 78482
# Number of data points in training set: 54937
# Number of data points in test set: 23545
# Ratio of train to test data: 30.00%

# %%
print(f'Train shape: {train.shape}')
print(f'Test shape: {test.shape}')
# Out:
# Train shape: (54937, 11)
# Test shape: (23545, 10)

# %%
train.head()
# Out:
#    Fuel Consumption City (l/100km)  Fuel Consumption Hwy (l/100km)  \
# 0                         0.710439                        1.589749
# 1                         1.007912                       -1.208539
# 2                         0.442528                        0.252161
# 3                        -0.254350                       -1.212116
# 4                        -1.145488                        0.373973
#
#    Fuel Consumption Comb (l/100km)  Engine Size(L)  Cylinders  Id  Make  \
# 0                         0.625417       -1.194897  -0.816938   1  16.0
# 1                        -1.205922        1.062403   0.526630   2  20.0
# 2                         0.388395       -0.743437  -0.816938   3  15.0
# 3                        -1.208809        2.570279   1.870199   4   4.0
# 4                        -1.198461       -0.924021  -0.816938   5  20.0
#
#    Vehicle Class  Transmission  Fuel Type  CO2 Emissions(g/km)
# 0           11.0          21.0        3.0                208.0
# 1            5.0           2.0        3.0                325.0
# 2            0.0          13.0        3.0                170.0
# 3           15.0           3.0        3.0                362.0
# 4            0.0          23.0        3.0                180.0

# %%
# Bagi data menjadi fitur dan target
X_train = train.drop(['CO2 Emissions(g/km)'], axis=1)
y_train = train['CO2 Emissions(g/km)']

X_test = test.copy()

# %%
from xgboost import XGBRegressor

params_xgb = {
    'objective': 'reg:squarederror',  # Specify the objective for regression tasks
    'colsample_bytree': 0.8,          # Fraction of features to be randomly sampled for each tree
    'learning_rate': 0.08,             # Step size shrinkage to prevent overfitting
    'max_depth': 128,                  # Maximum depth of a tree
    'alpha': 10,                      # L1 regularization term on weights
    'n_estimators': 10000,             # Number of boosting rounds
    'random_state': 472389
}

model_xgb = XGBRegressor(**params_xgb)

model_xgb.fit(X_train, y_train)
y_pred = model_xgb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 16
#      13 model_xgb = XGBRegressor(**params_xgb)
#      15 model_xgb.fit(X_train, y_train)
# ---> 16 y_pred = model_xgb.predict(X_test)
#
# File c:\Users\Mahardika\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1164, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1162 if self._can_use_inplace_predict():
#    1163     try:
# -> 1164         predts = self.get_booster().inplace_predict(
#    1165             data=X,
#    1166             iteration_range=iteration_range,
#    1167             predict_type="margin" if output_margin else "value",
#    1168             missing=self.missing,
#    1169             base_margin=base_margin,
#    1170             validate_features=validate_features,
#    1171         )
#    1172         if _is_cupy_array(predts):
#    1173             import cupy  # pylint: disable=import-error
#
# File c:\Users\Mahardika\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:2417, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2415     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2416     if validate_features:
# -> 2417         self._validate_features(fns)
#    2418 if _is_list(data) or _is_tuple(data):
#    2419     data = np.array(data)
#
# File c:\Users\Mahardika\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:2969, in Booster._validate_features(self, feature_names)
#    2963 if my_missing:
#    2964     msg += (
#    2965         "\ntraining data did not have the following fields: "
#    2966         + ", ".join(str(s) for s in my_missing)
#    2967     )
# -> 2969 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['Fuel Consumption City (l/100km)', 'Fuel Consumption Hwy (l/100km)', 'Fuel Consumption Comb (l/100km)', 'Engine Size(L)', 'Cylinders', 'Id', 'Make', 'Vehicle Class', 'Transmission', 'Fuel Type'] ['Fuel Consumption City (l/100km)', 'Engine Size(L)', 'Cylinders', 'Fuel Consumption Hwy (l/100km)', 'Fuel Consumption Comb (l/100km)', 'Id', 'Make', 'Vehicle Class', 'Transmission', 'Fuel Type']

# %%
test
# Out:
#        Fuel Consumption City (l/100km)  Fuel Consumption Hwy (l/100km)  \
# 0                             0.920593                       -0.865100
# 1                            -0.910920                       -0.939220
# 2                             1.964239                        0.589944
# 3                            -0.216649                        1.428867
# 4                            -0.258921                        1.915538
# ...                                ...                             ...
# 58771                         1.241548                       -0.233801
# 58772                        -0.188727                        0.037745
# 58773                         0.787471                        0.696299
# 58774                         0.073664                       -0.262323
# 58775                         1.420951                       -0.921756
#
#        Fuel Consumption Comb (l/100km)  Engine Size(L)  Cylinders      Id  \
# 0                             0.283683        0.748470   0.325779  137142
# 1                             1.495285        0.846481   0.608439  137143
# 2                             1.498660       -0.329646  -0.522202  137144
# 3                            -1.017581        1.728575   1.456420  137145
# 4                            -1.021649        1.532554   2.021740  137146
# ...                                ...             ...        ...     ...
# 58771                        -0.311042        0.454439  -0.239542  195913
# 58772                        -0.137411       -1.211740  -0.804862  195914
# 58773                         0.775921        0.650460   0.891099  195915
# 58774                        -0.091855        2.120617   2.021740  195916
# 58775                         0.509468        0.650460   0.608439  195917
#
#        Make  Vehicle Class  Transmission  Fuel Type
# 0         3            2.0          15.0        3.0
# 1         7           15.0          13.0        3.0
# 2        16           11.0          19.0        3.0
# 3        14            2.0          15.0        4.0
# 4         2           12.0          15.0        4.0
# ...     ...            ...           ...        ...
# 58771    11           11.0           3.0        3.0
# 58772     7            9.2          13.0        3.0
# 58773     4           12.0           3.0        3.0
# 58774     7            6.2          13.0        3.0
# 58775     0           11.0          16.0        4.0
#
# [58776 rows x 10 columns]

# %%
submission_3 = test.loc[:, ["Id"]]

submission_3['CO2 Emissions(g/km)'] = y_pred

# %%
submission_3
# Out:
#            Id  CO2 Emissions(g/km)
# 0      137142           242.520065
# 1      137143           347.479736
# 2      137144           211.449829
# 3      137145           285.716339
# 4      137146           314.794312
# ...       ...                  ...
# 58771  195913           265.171692
# 58772  195914           200.791443
# 58773  195915           298.636536
# 58774  195916           300.951630
# 58775  195917           256.270264
#
# [58776 rows x 2 columns]

# %%
import os

if not os.path.exists('../data/submission'):
    os.makedirs('../data/submission')

submission_3.to_csv('../data/submission/submission_6.csv', index=False)
