# %%
import pandas as pd
import numpy as np

train = pd.read_csv('../data/processed/preprocess_train_dataslayer.csv')
test = pd.read_csv('../data/processed/preprocess_test_dataslayer.csv')

train.head()
# Out:
#    Unnamed: 0  Id  Fuel Type  Transmission (Type)  Vehicle Class (Function)  \
# 0           0   1          3                    0                         7
# 1           1   2          1                    0                         7
# 2           2   3          4                    4                         8
# 3           3   4          3                    2                         6
# 4           4   5          4                    2                         4
#
#    Vehicle Class (Type)  Make  Engine Size(L)  Cylinders  \
# 0                     1     7        3.500000   6.000000
# 1                     1     4        5.300000   5.157514
# 2                     4     2        4.400000   5.157514
# 3                     4    11        2.989195   4.000000
# 4                     4     1        3.000000   6.000000
#
#    Transmission (Gears)  Fuel Consumption City (Value)  \
# 0              6.000000                         864.00
# ...

# %%
train.shape
# Out:
# (137141, 14)
